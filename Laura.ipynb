# %%
import pandas as pd

# %%
df = pd.read_csv("caso.csv.gz", compression='gzip')

# %%
df.head()
# Out:
#          date state  ... confirmed_per_100k_inhabitants death_rate
# 0  2021-07-07    AP  ...                    13722.52322     0.0157
# 1  2021-07-06    AP  ...                    13700.35961     0.0157
# 2  2021-07-05    AP  ...                    13684.23007     0.0157
# 3  2021-07-04    AP  ...                    13668.33261     0.0157
# 4  2021-07-03    AP  ...                    13650.34644     0.0157
#
# [5 rows x 13 columns]

# %%
df[df.confirmed > 3000000][['confirmed', 'city', 'state', 'deaths']]
# Out:
#          confirmed city state  deaths
# 1955134    3824111  NaN    SP  130935
# 1955135    3809222  NaN    SP  130389
# 1955136    3790090  NaN    SP  129675
# 1955137    3785859  NaN    SP  129609
# 1955138    3779408  NaN    SP  129453
# 1955139    3762758  NaN    SP  128921
# 1955140    3743291  NaN    SP  128322
# 1955141    3727348  NaN    SP  127681
# 1955142    3719586  NaN    SP  126937
# 1955143    3700378  NaN    SP  126112
# 1955144    3696093  NaN    SP  126050
# 1955145    3688128  NaN    SP  125916
# 1955146    3669196  NaN    SP  125378
# 1955147    3648202  NaN    SP  124606
# 1955148    3630251  NaN    SP  123825
# 1955149    3610743  NaN    SP  123101
# 1955150    3587646  NaN    SP  122258
# 1955151    3582792  NaN    SP  122160
# 1955152    3573210  NaN    SP  121960
# 1955153    3552727  NaN    SP  121238
# 1955154    3525021  NaN    SP  120524
# 1955155    3509967  NaN    SP  119905
# 1955156    3487385  NaN    SP  119110
# 1955157    3464158  NaN    SP  118213
# ...
