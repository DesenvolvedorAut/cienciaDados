# %%
import pandas as pd

# %%
t = pd.read_csv('caso.csv.gz', compression='gzip')

# %%
t[t.city == 'São Paulo']
# Out:
#                date state  ... confirmed_per_100k_inhabitants death_rate
# 2188905  2021-07-06    SP  ...                     7027.85960     0.0392
# 2188906  2021-07-05    SP  ...                     7006.61050     0.0392
# 2188907  2021-07-04    SP  ...                     7002.63492     0.0392
# 2188908  2021-07-03    SP  ...                     6996.90683     0.0392
# 2188909  2021-07-02    SP  ...                     6975.37377     0.0392
# ...             ...   ...  ...                            ...        ...
# 2189367  2020-02-29    SP  ...                        0.01623     0.0000
# 2189368  2020-02-28    SP  ...                        0.01623     0.0000
# 2189369  2020-02-27    SP  ...                        0.00811     0.0000
# 2189370  2020-02-26    SP  ...                        0.00811     0.0000
# 2189371  2020-02-25    SP  ...                        0.00811     0.0000
#
# [467 rows x 13 columns]

# %%
t[t.city == 'São Paulo'][['city', 'state', 'deaths', 'confirmed']]
# Out:
#               city state  deaths  confirmed
# 2188905  São Paulo    SP   33956     866200
# 2188906  São Paulo    SP   33820     863581
# 2188907  São Paulo    SP   33806     863091
# 2188908  São Paulo    SP   33798     862385
# 2188909  São Paulo    SP   33713     859731
# ...            ...   ...     ...        ...
# 2189367  São Paulo    SP       0          2
# 2189368  São Paulo    SP       0          2
# 2189369  São Paulo    SP       0          1
# 2189370  São Paulo    SP       0          1
# 2189371  São Paulo    SP       0          1
#
# [467 rows x 4 columns]
